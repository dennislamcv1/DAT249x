# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option("display.max_columns",60)

# %%
df = pd.read_csv("compas-scores-two-years-violent.csv")

# %%
df.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   5         marcu brown   marcu        brown            2013-01-13  Male
# 3   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
# 4   7        marsha miles  marsha        miles            2013-11-30  Male
#
#           dob  age          age_cat              race  juv_fel_count  \
# 0  1947-04-18   69  Greater than 45             Other              0
# 1  1982-01-22   34          25 - 45  African-American              0
# 2  1993-01-21   23     Less than 25  African-American              0
# 3  1973-01-22   43          25 - 45             Other              0
# 4  1971-08-22   44          25 - 45             Other              0
#
#    decile_score  juv_misd_count  juv_other_count  priors_count  \
# ...

# %%
df.tail()
# Out:
#          id             name    first     last compas_screening_date     sex  \
# 4738  10995     raheem smith   raheem    smith            2013-10-20    Male
# 4739  10996    steven butler   steven   butler            2013-11-23    Male
# 4740  10997  malcolm simmons  malcolm  simmons            2014-02-01    Male
# 4741  10999  winston gregory  winston  gregory            2014-01-14    Male
# 4742  11000      farrah jean   farrah     jean            2014-03-09  Female
#
#              dob  age          age_cat              race  juv_fel_count  \
# 4738  1995-06-28   20     Less than 25  African-American              0
# 4739  1992-07-17   23     Less than 25  African-American              0
# 4740  1993-03-25   23     Less than 25  African-American              0
# 4741  1958-10-01   57  Greater than 45             Other              0
# 4742  1982-11-17   33          25 - 45  African-American              0
#
#       decile_score  juv_misd_count  juv_other_count  priors_count  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4743 entries, 0 to 4742
# Data columns (total 54 columns):
# id                         4743 non-null int64
# name                       4743 non-null object
# first                      4743 non-null object
# last                       4743 non-null object
# compas_screening_date      4743 non-null object
# sex                        4743 non-null object
# dob                        4743 non-null object
# age                        4743 non-null int64
# age_cat                    4743 non-null object
# race                       4743 non-null object
# juv_fel_count              4743 non-null int64
# decile_score               4743 non-null int64
# juv_misd_count             4743 non-null int64
# juv_other_count            4743 non-null int64
# priors_count               4743 non-null int64
# days_b_screening_arrest    4475 non-null float64
# c_jail_in                  4475 non-null object
# ...

# %%
df.describe()
# Out:
#                  id          age  juv_fel_count  decile_score  juv_misd_count  \
# count   4743.000000  4743.000000    4743.000000   4743.000000     4743.000000
# mean    5454.230445    36.002952       0.045330      3.978073        0.070841
# std     3189.515451    12.200715       0.420694      2.749706        0.406142
# min        1.000000    18.000000       0.000000     -1.000000        0.000000
# 25%     2631.000000    26.000000       0.000000      1.000000        0.000000
# 50%     5475.000000    33.000000       0.000000      3.000000        0.000000
# 75%     8239.500000    44.000000       0.000000      6.000000        0.000000
# max    11000.000000    83.000000      20.000000     10.000000        8.000000
#
#        juv_other_count  priors_count  days_b_screening_arrest  \
# count      4743.000000   4743.000000              4475.000000
# mean          0.080751      2.677209                 2.723799
# std           0.468779      4.084277                78.074361
# ...

# %%
sns.distplot(df.age)
plt.show()

# %%
sns.distplot(df.is_recid)
plt.show()

# %%
sns.distplot(df.is_violent_recid)
plt.show()

# %%
sns.distplot(df.two_year_recid)
plt.show()

# %%
sns.distplot(df['two_year_recid.1'])
plt.show()

# %%
numeric = df[['age','juv_fel_count','priors_count',]]

# %%
numeric.shape
# Out:
# (4743, 3)

# %%
numeric.corr()
# Out:
#                     age  juv_fel_count  priors_count
# age            1.000000      -0.054053      0.102593
# juv_fel_count -0.054053       1.000000      0.195438
# priors_count   0.102593       0.195438      1.000000

# %%
sns.heatmap(numeric.corr(),annot=True)
